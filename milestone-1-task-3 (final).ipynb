# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report
from tensorflow.keras import regularizers

# %%
df = pd.read_csv('/kaggle/input/task-3-with-inference/AirlineScrappedReview_withSentiment.csv')

# Quick look
df.head()
# Out:
#   Passanger_Name Flying_Date                  Route  Rating       Verified  \
# 0     Paige Boet   June 2023  New Orleans to London       1  Trip Verified
# 1        S Layne  March 2023        London to Amman       1  Trip Verified
# 2    E Lanewoski         NaN     Heathrow to Bodrum       2  Trip Verified
# 3    Joel Burman   June 2023        Amman to London       4   Not Verified
# 4        R Vines         NaN   London City to Ibiza       7  Trip Verified
#
#                              Review_title  \
# 0             The airline lost my luggage
# 1  fully refunded by our travel insurance
# 2             no boarding drinks provided
# 3                       WiFi didn't work
# 4                      stick with economy
#
#                                       Review_content  Traveller_Type  \
# 0  The airline lost my luggage and was absolutely...    Solo Leisure
# 1  We booked on the BA website, round trip flight...  Couple Leisure
# 2  First time flying with BA business class, neve...    Solo Leisure
# 3  You can buy sandwiches and crisps but don't ex...    Solo Leisure
# 4  This is a two-for-one review covering economy ...  Family Leisure
#
#             Class   Start_Location  ... Start_Latitude Start_Longitude  \
# 0   Economy Class      New Orleans  ...      29.975998      -90.078213
# 1  Business Class           London  ...      51.507446       -0.127765
# 2  Business Class  London Heathrow  ...      51.467739       -0.458780
# 3   Economy Class            Amman  ...      31.951569       35.923963
# 4  Business Class      London City  ...      42.953765      -81.229153
#
#                                        Start_Address  End_Latitude  \
# 0  New Orleans, Orleans Parish, Louisiana, United...     51.507446
# 1    London, Greater London, England, United Kingdom     31.951569
# 2  London Heathrow Airport, The Beacon Roundabout...     37.034399
# 3  عمان, ناحية عمان, لواء قصبة عمان, عمان, 11110,...     51.507446
# 4            London (city), Ontario, N6C 0A7, Canada     38.974390
#
#   End_Longitude                                        End_Address  \
# 0     -0.127765    London, Greater London, England, United Kingdom
# 1     35.923963  عمان, ناحية عمان, لواء قصبة عمان, عمان, 11110,...
# 2     27.430651                Bodrum, Muğla, Ege Bölgesi, Türkiye
# 3     -0.127765    London, Greater London, England, United Kingdom
# 4      1.419746                     Eivissa, Illes Balears, España
#
#                                          Review_text Sentiment_score  \
# 0  The airline lost my luggage. The airline lost ...         -0.8315
# 1  fully refunded by our travel insurance. We boo...          0.7184
# 2  no boarding drinks provided. First time flying...         -0.7964
# 3  WiFi didn't work . You can buy sandwiches and ...         -0.5849
# 4  stick with economy. This is a two-for-one revi...          0.9657
#
#   Sentiment_label  satisfaction
# 0        Negative             0
# 1        Positive             0
# 2        Negative             0
# 3        Negative             0
# 4        Positive             1
#
# [5 rows x 22 columns]

# %%
df['Verified'] = df['Verified'].apply(lambda x: 1 if x == 'Trip Verified' else 0)

# %%
X = df[['Traveller_Type', 'Class', 'Route', 'Sentiment_score', 'Verified']]
y = df['satisfaction']

categorical_cols = ['Traveller_Type', 'Class', 'Route']
numeric_cols = ['Sentiment_score', 'Verified']

X_encoded = pd.get_dummies(X, columns=categorical_cols, drop_first=True)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

X_train, X_test, y_train, y_test = train_test_split(
    X_encoded, y, test_size=0.2, random_state=42, stratify=y
)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from tensorflow.keras import Sequential, layers, regularizers
from tensorflow.keras.metrics import Precision, Recall

model = Sequential([
    layers.Input(shape=(X_train.shape[1],)),
    layers.Dense(8, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
    layers.Dropout(0.2),
    layers.Dense(4, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
    layers.Dropout(0.2),
    layers.Dense(1, activation='sigmoid')
])

model.summary()

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy', Precision(name='precision'), Recall(name='recall')]
)
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_6 (Dense)                 │ (None, 8)              │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 8)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 4)              │            36 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 4)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 1)              │             5 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 12,457 (48.66 KB)
#  Trainable params: 12,457 (48.66 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

early_stop = EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True,
    verbose=1
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=3,
    min_lr=0.00001,
    verbose=1
)

history = model.fit(
    X_train, y_train, 
    epochs=50,
    validation_split=0.2,
    callbacks=[early_stop, reduce_lr],
    verbose=1
)
# Out:
# Epoch 1/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.4739 - loss: 0.9115 - precision: 0.4476 - recall: 0.4730 - val_accuracy: 0.4913 - val_loss: 0.7806 - val_precision: 0.4855 - val_recall: 0.4735 - learning_rate: 0.0010
# Epoch 2/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5835 - loss: 0.7432 - precision: 0.5821 - recall: 0.4130 - val_accuracy: 0.5210 - val_loss: 0.7556 - val_precision: 0.5542 - val_recall: 0.1625 - learning_rate: 0.0010
# Epoch 3/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6391 - loss: 0.6949 - precision: 0.6609 - recall: 0.4552 - val_accuracy: 0.5297 - val_loss: 0.7501 - val_precision: 0.5897 - val_recall: 0.1625 - learning_rate: 0.0010
# Epoch 4/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6658 - loss: 0.6646 - precision: 0.7275 - recall: 0.4586 - val_accuracy: 0.5297 - val_loss: 0.7438 - val_precision: 0.5897 - val_recall: 0.1625 - learning_rate: 0.0010
# Epoch 5/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6908 - loss: 0.6171 - precision: 0.8138 - recall: 0.4719 - val_accuracy: 0.5437 - val_loss: 0.7393 - val_precision: 0.6341 - val_recall: 0.1837 - learning_rate: 0.0010
# Epoch 6/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7016 - loss: 0.5987 - precision: 0.8215 - recall: 0.4643 - val_accuracy: 0.5717 - val_loss: 0.7292 - val_precision: 0.6827 - val_recall: 0.2509 - learning_rate: 0.0010
# Epoch 7/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7687 - loss: 0.5356 - precision: 0.8152 - recall: 0.6669 - val_accuracy: 0.6381 - val_loss: 0.7000 - val_precision: 0.7375 - val_recall: 0.4170 - learning_rate: 0.0010
# Epoch 8/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8160 - loss: 0.4956 - precision: 0.8302 - recall: 0.7695 - val_accuracy: 0.6416 - val_loss: 0.6754 - val_precision: 0.7216 - val_recall: 0.4488 - learning_rate: 0.0010
# Epoch 9/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8335 - loss: 0.4587 - precision: 0.8196 - recall: 0.8217 - val_accuracy: 0.6906 - val_loss: 0.6480 - val_precision: 0.7598 - val_recall: 0.5477 - learning_rate: 0.0010
# Epoch 10/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8614 - loss: 0.4317 - precision: 0.8370 - recall: 0.8654 - val_accuracy: 0.7692 - val_loss: 0.6366 - val_precision: 0.7849 - val_recall: 0.7350 - learning_rate: 0.0010
# Epoch 11/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8643 - loss: 0.4180 - precision: 0.8346 - recall: 0.8869 - val_accuracy: 0.7710 - val_loss: 0.6183 - val_precision: 0.7639 - val_recall: 0.7774 - learning_rate: 0.0010
# Epoch 12/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8717 - loss: 0.3970 - precision: 0.8422 - recall: 0.8938 - val_accuracy: 0.7762 - val_loss: 0.6201 - val_precision: 0.7969 - val_recall: 0.7350 - learning_rate: 0.0010
# Epoch 13/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8784 - loss: 0.3882 - precision: 0.8665 - recall: 0.8868 - val_accuracy: 0.7605 - val_loss: 0.6233 - val_precision: 0.7786 - val_recall: 0.7208 - learning_rate: 0.0010
# Epoch 14/50
# 64/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8878 - loss: 0.3773 - precision: 0.8668 - recall: 0.9047
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8868 - loss: 0.3777 - precision: 0.8668 - recall: 0.9023 - val_accuracy: 0.7605 - val_loss: 0.6283 - val_precision: 0.8017 - val_recall: 0.6855 - learning_rate: 0.0010
# Epoch 15/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8912 - loss: 0.3654 - precision: 0.8725 - recall: 0.9078 - val_accuracy: 0.7745 - val_loss: 0.6180 - val_precision: 0.7873 - val_recall: 0.7456 - learning_rate: 5.0000e-04
# Epoch 16/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8852 - loss: 0.3547 - precision: 0.8657 - recall: 0.8983 - val_accuracy: 0.7815 - val_loss: 0.6189 - val_precision: 0.7948 - val_recall: 0.7527 - learning_rate: 5.0000e-04
# Epoch 17/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8927 - loss: 0.3484 - precision: 0.8844 - recall: 0.8936 - val_accuracy: 0.7850 - val_loss: 0.6098 - val_precision: 0.7797 - val_recall: 0.7880 - learning_rate: 5.0000e-04
# Epoch 18/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8970 - loss: 0.3355 - precision: 0.8879 - recall: 0.8953 - val_accuracy: 0.7675 - val_loss: 0.6133 - val_precision: 0.7841 - val_recall: 0.7314 - learning_rate: 5.0000e-04
# Epoch 19/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9048 - loss: 0.3356 - precision: 0.8982 - recall: 0.9038 - val_accuracy: 0.7780 - val_loss: 0.6117 - val_precision: 0.7977 - val_recall: 0.7385 - learning_rate: 5.0000e-04
# Epoch 20/50
# 64/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9157 - loss: 0.3279 - precision: 0.9006 - recall: 0.9199
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9146 - loss: 0.3287 - precision: 0.9003 - recall: 0.9185 - val_accuracy: 0.7675 - val_loss: 0.6172 - val_precision: 0.7976 - val_recall: 0.7102 - learning_rate: 5.0000e-04
# Epoch 21/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9041 - loss: 0.3419 - precision: 0.8832 - recall: 0.9211 - val_accuracy: 0.7797 - val_loss: 0.6046 - val_precision: 0.7774 - val_recall: 0.7774 - learning_rate: 2.5000e-04
# Epoch 22/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9109 - loss: 0.3385 - precision: 0.9025 - recall: 0.9141 - val_accuracy: 0.7710 - val_loss: 0.6057 - val_precision: 0.7734 - val_recall: 0.7597 - learning_rate: 2.5000e-04
# Epoch 23/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8967 - loss: 0.3255 - precision: 0.8884 - recall: 0.8960 - val_accuracy: 0.7762 - val_loss: 0.5999 - val_precision: 0.7778 - val_recall: 0.7668 - learning_rate: 2.5000e-04
# Epoch 24/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8994 - loss: 0.3302 - precision: 0.8986 - recall: 0.8859 - val_accuracy: 0.7727 - val_loss: 0.6052 - val_precision: 0.7802 - val_recall: 0.7527 - learning_rate: 2.5000e-04
# Epoch 25/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9067 - loss: 0.3176 - precision: 0.9132 - recall: 0.8972 - val_accuracy: 0.7745 - val_loss: 0.6031 - val_precision: 0.7810 - val_recall: 0.7562 - learning_rate: 2.5000e-04
# Epoch 26/50
# 65/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9043 - loss: 0.3273 - precision: 0.8989 - recall: 0.9018
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9044 - loss: 0.3265 - precision: 0.8991 - recall: 0.9017 - val_accuracy: 0.7797 - val_loss: 0.6045 - val_precision: 0.7774 - val_recall: 0.7774 - learning_rate: 2.5000e-04
# Epoch 27/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9014 - loss: 0.3311 - precision: 0.8969 - recall: 0.9019 - val_accuracy: 0.7745 - val_loss: 0.6025 - val_precision: 0.7730 - val_recall: 0.7703 - learning_rate: 1.2500e-04
# Epoch 28/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9101 - loss: 0.3218 - precision: 0.9068 - recall: 0.9051 - val_accuracy: 0.7745 - val_loss: 0.6021 - val_precision: 0.7730 - val_recall: 0.7703 - learning_rate: 1.2500e-04
# Epoch 28: early stopping
# Restoring model weights from the end of the best epoch: 23.

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

y_pred_probs = model.predict(X_test)

y_pred = (y_pred_probs > 0.5).astype(int)

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print("Test Accuracy:", round(accuracy, 3))
print("Test Precision:", round(precision, 3))
print("Test Recall:", round(recall, 3))
print("Test F1-Score:", round(f1, 3))

print("\nDetailed classification report:")
print(classification_report(y_test, y_pred))
# Out:
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Test Accuracy: 0.766
# Test Precision: 0.755
# Test Recall: 0.762
# Test F1-Score: 0.758
#
# Detailed classification report:
#               precision    recall  f1-score   support
#
#            0       0.78      0.77      0.77       371
#            1       0.76      0.76      0.76       344
#
#     accuracy                           0.77       715
#    macro avg       0.77      0.77      0.77       715
# weighted avg       0.77      0.77      0.77       715

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.show()

# %% [markdown]
# # **The inference Function**

# %%
def predict_satisfaction(traveller_type, travel_class, route, sentiment_score, verified):
    """
    Returns satisfaction prediction (1 = satisfied, 0 = not satisfied)
    given raw input fields.
    """
    # Step 1: Build a dataframe from input
    input_df = pd.DataFrame([{
        'Traveller_Type': traveller_type,
        'Class': travel_class,
        'Route': route,
        'Sentiment_score': sentiment_score,
        'Verified': 1 if verified == 'Trip Verified' or verified == 1 else 0
    }])
    
    # Step 2: One-hot encode (same as training)
    input_encoded = pd.get_dummies(input_df, columns=['Traveller_Type', 'Class', 'Route'], drop_first=True)
    
    # Step 3: Align with training columns efficiently
    missing_cols = set(X_encoded.columns) - set(input_encoded.columns)
    
    # Convert to list before using as DataFrame columns
    if missing_cols:
        missing_df = pd.DataFrame(0, index=np.arange(len(input_encoded)), columns=list(missing_cols))
        input_encoded = pd.concat([input_encoded, missing_df], axis=1)
    
    # Reorder to match training columns
    input_encoded = input_encoded[X_encoded.columns]
    
    # Step 4: Scale
    input_scaled = scaler.transform(input_encoded)
    
    # Step 5: Predict
    pred_prob = model.predict(input_scaled, verbose=0)[0][0]
    pred_label = int(pred_prob > 0.5)
    
    # Step 6: Return result
    result = "Satisfied" if pred_label == 1 else "Not Satisfied"
    print(f"Predicted Probability: {pred_prob:.3f}")
    print(f"Predicted Satisfaction: {result}")
    
    return result

# %%
predict_satisfaction(
    traveller_type='Leisure traveller',
    travel_class='Economy Class',
    route='London to New York',
    sentiment_score=0.75,
    verified='Trip Verified'
)
# Out:
# Predicted Probability: 0.657
# Predicted Satisfaction: Satisfied
# 'Satisfied'
